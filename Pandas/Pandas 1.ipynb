# %%
# Welcome to my pandas course
import pandas as pd

# %%
#We can install and load the csv data to our notebook, 
#df mean dataframe 
df = pd.read_csv(r'C:\Users\lian.s\Downloads\Mall_Customers.csv', index_col = "Age")

# %%
#printing out the data we loaded
df
# Out:
#      CustomerID   Genre  Annual Income (k$)  Spending Score (1-100)
# Age
# 19            1    Male                  15                      39
# 21            2    Male                  15                      81
# 20            3  Female                  16                       6
# 23            4  Female                  16                      77
# 31            5  Female                  17                      40
# ..          ...     ...                 ...                     ...
# 35          196  Female                 120                      79
# 45          197  Female                 126                      28
# 32          198    Male                 126                      74
# 32          199    Male                 137                      18
# 30          200    Male                 137                      83
#
# [200 rows x 4 columns]

# %%
#shows the number of columns an rows in the dataset
df.shape
# Out:
# (200, 4)

# %%
#more precise method of analysing the columns and rows of a dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 19 to 30
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Annual Income (k$)      200 non-null    int64
#  3   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.8+ KB

# %%
pd.set_option('display.max_columns', 5)
pd.set_option('display.max_rows', 200)

# %%
#provides description of the rows/columns
schema_df = pd.read_csv(r'C:\Users\lian.s\Downloads\Mall_Customers.csv', index_col = "Age")

# %%
schema_df
# Out:
#      CustomerID   Genre  Annual Income (k$)  Spending Score (1-100)
# Age
# 19            1    Male                  15                      39
# 21            2    Male                  15                      81
# 20            3  Female                  16                       6
# 23            4  Female                  16                      77
# 31            5  Female                  17                      40
# 22            6  Female                  17                      76
# 35            7  Female                  18                       6
# 23            8  Female                  18                      94
# 64            9    Male                  19                       3
# 30           10  Female                  19                      72
# 67           11    Male                  19                      14
# 35           12  Female                  19                      99
# 58           13  Female                  20                      15
# ...

# %%
#to print the 1st five values you call in the line below;
df.head()
# Out:
#      CustomerID   Genre  Annual Income (k$)  Spending Score (1-100)
# Age
# 19            1    Male                  15                      39
# 21            2    Male                  15                      81
# 20            3  Female                  16                       6
# 23            4  Female                  16                      77
# 31            5  Female                  17                      40

# %%
#and to print the last 5 values, we call,
df.tail()
# Out:
#      CustomerID   Genre  Annual Income (k$)  Spending Score (1-100)
# Age
# 35          196  Female                 120                      79
# 45          197  Female                 126                      28
# 32          198    Male                 126                      74
# 32          199    Male                 137                      18
# 30          200    Male                 137                      83

# %%
#Let's see how many females and males participated in the survey
df['Genre'].value_counts()
# Out:
# Female    112
# Male       88
# Name: Genre, dtype: int64

# %%
schema_df
# Out:
#      CustomerID   Genre  Annual Income (k$)  Spending Score (1-100)
# Age
# 19            1    Male                  15                      39
# 21            2    Male                  15                      81
# 20            3  Female                  16                       6
# 23            4  Female                  16                      77
# 31            5  Female                  17                      40
# 22            6  Female                  17                      76
# 35            7  Female                  18                       6
# 23            8  Female                  18                      94
# 64            9    Male                  19                       3
# 30           10  Female                  19                      72
# 67           11    Male                  19                      14
# 35           12  Female                  19                      99
# 58           13  Female                  20                      15
# ...

# %%
schema_df.sort_index()
# Out:
#      CustomerID   Genre  Annual Income (k$)  Spending Score (1-100)
# Age
# 18          115  Female                  65                      48
# 18           92    Male                  59                      41
# 18           66    Male                  48                      59
# 18           34    Male                  33                      92
# 19            1    Male                  15                      39
# 19          163    Male                  81                       5
# 19          139    Male                  74                      10
# 19          116  Female                  65                      50
# 19          114    Male                  64                      46
# 19          112  Female                  63                      54
# 19           69    Male                  48                      59
# 19           62    Male                  46                      55
# 20          135    Male                  73                       5
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#      CustomerID   Genre  Annual Income (k$)  Spending Score (1-100)
# Age
# 70           71    Male                  49                      55
# 70           61    Male                  46                      56
# 69           58    Male                  44                      46
# 68           91  Female                  59                      55
# 68           68  Female                  48                      48
# 68          109    Male                  63                      43
# 67           83    Male                  54                      41
# 67           11    Male                  19                      14
# 67          103    Male                  62                      59
# 67           63  Female                  47                      52
# 66          107  Female                  63                      50
# 66          110    Male                  63                      48
# 65           41  Female                  38                      35
# ...

# %%
#Since we're trying to analyze which gender spends more, we can filter out the spending
high_spending_score = (df['Spending Score (1-100)']>70)

# %%
df.loc[high_spending_score]
# Out:
#      CustomerID   Genre  Annual Income (k$)  Spending Score (1-100)
# Age
# 21            2    Male                  15                      81
# 23            4  Female                  16                      77
# 22            6  Female                  17                      76
# 23            8  Female                  18                      94
# 30           10  Female                  19                      72
# 35           12  Female                  19                      99
# 24           14  Female                  20                      77
# 22           16    Male                  20                      79
# 35           20  Female                  23                      98
# 25           22    Male                  24                      73
# 31           24    Male                  25                      73
# 29           26    Male                  28                      82
# 23           30  Female                  29                      87
# ...

# %%
#Lets use a string to call the highest spending only done by females
filt = df['Genre'].str.contains('Female', na= False) & (df['Spending Score (1-100)']>70)

# %%
df[filt]
# Out:
#      CustomerID   Genre  Annual Income (k$)  Spending Score (1-100)
# Age
# 23            4  Female                  16                      77
# 22            6  Female                  17                      76
# 23            8  Female                  18                      94
# 30           10  Female                  19                      72
# 35           12  Female                  19                      99
# 24           14  Female                  20                      77
# 35           20  Female                  23                      98
# 23           30  Female                  29                      87
# 21           32  Female                  30                      73
# 21           36  Female                  33                      81
# 30           38  Female                  34                      73
# 20           40  Female                  37                      75
# 31          126  Female                  70                      77
# ...

# %%
#Let's update some values in our dataframe
df.columns
# Out:
# Index(['CustomerID', 'Genre', 'Annual Income (k$)', 'Spending Score (1-100)'], dtype='object')

# %%
#We begin by renaming the columns
df.columns = ['Id','Gender','Income in $(1000)','Spending_Score']

# %%
df.columns
# Out:
# Index(['Id', 'Gender', 'Income in $(1000)', 'Spending_Score'], dtype='object')

# %%
#Then we reset back the index making age a column in the DF again
df.reset_index(inplace=True)
df
# Out:
#      Age   Id  Gender  Income in $(1000)  Spending_Score
# 0     19    1    Male                 15              39
# 1     21    2    Male                 15              81
# 2     20    3  Female                 16               6
# 3     23    4  Female                 16              77
# 4     31    5  Female                 17              40
# 5     22    6  Female                 17              76
# 6     35    7  Female                 18               6
# 7     23    8  Female                 18              94
# 8     64    9    Male                 19               3
# 9     30   10  Female                 19              72
# 10    67   11    Male                 19              14
# 11    35   12  Female                 19              99
# 12    58   13  Female                 20              15
# 13    24   14  Female                 20              77
# 14    37   15    Male                 20              13
# ...

# %%
#Afterwards we convert the column names to uppercase
df.columns = [x.upper() for x in df.columns]
df
# Out:
#      AGE   ID  GENDER  INCOME IN $(1000)  SPENDING_SCORE
# 0     19    1    Male                 15              39
# 1     21    2    Male                 15              81
# 2     20    3  Female                 16               6
# 3     23    4  Female                 16              77
# 4     31    5  Female                 17              40
# 5     22    6  Female                 17              76
# 6     35    7  Female                 18               6
# 7     23    8  Female                 18              94
# 8     64    9    Male                 19               3
# 9     30   10  Female                 19              72
# 10    67   11    Male                 19              14
# 11    35   12  Female                 19              99
# 12    58   13  Female                 20              15
# 13    24   14  Female                 20              77
# 14    37   15    Male                 20              13
# ...

# %%
df.sort_values(by = ['GENDER', 'INCOME IN $(1000)'], inplace =True )

# %%
df[['GENDER','INCOME IN $(1000)']].head(50)
# Out:
#     GENDER  INCOME IN $(1000)
# 2   Female                 16
# 3   Female                 16
# 4   Female                 17
# 5   Female                 17
# 6   Female                 18
# 7   Female                 18
# 9   Female                 19
# 11  Female                 19
# 12  Female                 20
# 13  Female                 20
# 16  Female                 21
# 19  Female                 23
# 22  Female                 25
# 24  Female                 28
# 26  Female                 28
# 28  Female                 29
# 29  Female                 29
# 31  Female                 30
# 34  Female                 33
# 35  Female                 33
# 36  Female                 34
# 37  Female                 34
# 38  Female                 37
# 39  Female                 37
# 40  Female                 38
# 43  Female                 39
# 44  Female                 39
# 45  Female                 39
# 46  Female                 40
# 47  Female                 40
# ...

# %%
df['INCOME IN $(1000)'].median()
# Out:
# 61.5

# %%
df.median()
# Out:
# C:\Users\lian.s\AppData\Local\Temp/ipykernel_6332/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# AGE                   36.0
# ID                   100.5
# INCOME IN $(1000)     61.5
# SPENDING_SCORE        50.0
# dtype: float64

# %%
df.describe()
# Out:
#               AGE          ID  INCOME IN $(1000)  SPENDING_SCORE
# count  200.000000  200.000000         200.000000      200.000000
# mean    38.850000  100.500000          60.560000       50.200000
# std     13.969007   57.879185          26.264721       25.823522
# min     18.000000    1.000000          15.000000        1.000000
# 25%     28.750000   50.750000          41.500000       34.750000
# 50%     36.000000  100.500000          61.500000       50.000000
# 75%     49.000000  150.250000          78.000000       73.000000
# max     70.000000  200.000000         137.000000       99.000000

# %%
df['GENDER'].value_counts()
# Out:
# Female    112
# Male       88
# Name: GENDER, dtype: int64

# %%
gender_grp = df.groupby(['GENDER'])

# %%
gender_grp.get_group('Female')
# Out:
#      AGE   ID  GENDER  INCOME IN $(1000)  SPENDING_SCORE
# 2     20    3  Female                 16               6
# 3     23    4  Female                 16              77
# 4     31    5  Female                 17              40
# 5     22    6  Female                 17              76
# 6     35    7  Female                 18               6
# 7     23    8  Female                 18              94
# 9     30   10  Female                 19              72
# 11    35   12  Female                 19              99
# 12    58   13  Female                 20              15
# 13    24   14  Female                 20              77
# 16    35   17  Female                 21              35
# 19    35   20  Female                 23              98
# 22    46   23  Female                 25               5
# 24    54   25  Female                 28              14
# 26    45   27  Female                 28              32
# ...

# %%
#Let's aggregate what gender makes the most income from the survey
gender_grp['INCOME IN $(1000)'].agg(['median','mean'])
# Out:
#         median       mean
# GENDER
# Female    60.0  59.250000
# Male      62.5  62.227273
